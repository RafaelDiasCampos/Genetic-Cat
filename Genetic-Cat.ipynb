# %% [markdown]
# # Genetic hash mask generator
#
# In this project, our goal is to use a genetic algorithm to find the most efficient masks for breaking passwords using a brute-force program such as hashcat or jhon-the-ripper.
#
# ## Requirements
#
# We start with a wordlist (in our case we used weakpass_4), that gets stored in wordlists/original/weakpass_4.txt.
# This wordlist contains a list of newline-separated passwords that will be our goal to break with the masks we generate.

# %% [markdown]
# ## Step 1: Prepare the wordlist for usage
#
# We need to make some changes to our wordlist before being able to use it.
#
# ### Step 1.1: Separate wordlist into the password length
#
# Our first step for preparing the wordlist is diving it into smaller lists based on the length of the password.
# The chosen wordlist (weakpass_4) has passwords that go from 1 to 30 characters, so after this step we should end with 30 smaller wordlists in the wordlists/processed folder.
#
# In this step we also filter passwords that don't match the masks we will generate in the next steps (comprised of at most the ?a charset in hashcat).

# %%
# %%script echo skipping
#
# wordlist_path = "wordlists/original/weakpass_4.txt"
# output_path = "wordlists/processed"
#
# !python scripts/splitWordlist.py -i $wordlist_path -o $output_path
# Out:
# skipping

# %% [markdown]
# ### Step 1.2: Sort and remove duplicates from the wordlists
#
# The next step is to remove any duplicate passwords from each of the wordlists, so we don´t have unecessary data.
#
# Immediately after, we sort the wordlist and overwrite the original one.
# This part is necessary for speeding up the next step, which is to create a search tree from the wordlist.
#
# WARNING: The sorting part wasn't done in an optimal way and may require a lot of memory to complete

# %%
# %%script echo skipping
#
# processed_wordlist_path = "wordlists/processed"
#
# !python scripts/sortAndUniqueWordlists.py -i $processed_wordlist_path
# Out:
# skipping

# %% [markdown]
# ### Step 1.3: Create the search tree for the wordlists:
#
# In order to drastically improve the speed of finding the number of password a mask matches in the wordlist, and to drastically reduce the memory usage, we create a search tree for each wordlist.
#
# This tree stores the matches of each charset of the mask, recursively. This way, finding the matches of a given mask requires simply traversing the tree once and getting the value at the leaf node.
#
# To create the tree, a binary search is performed in the sorted wordlist, repeatedly recursevely for each character in the password.
#
# In this step, we also define a maximum depth for the tree. Wordlists with a passord length greater than the maximum depth are not processed.
# This is done because the size of the tree grows exponentially with the length of the password, and at the same time, long passwords are used much less frequently.
# Due to these reasons, it makes more sense to use other ways to check the number of matches of a long mask (such as using a regex in the file).

# %%
# %%script echo skipping
#
# processed_wordlist_path = "wordlists/processed"
# tree_path = "wordlists/trees"
# max_depth = 15
#
# !python scripts/createWordlistTree.py -i $processed_wordlist_path -o $tree_path -d $max_depth
# Out:
# skipping

# %% [markdown]
# ## Step 2: Evaluate the metric of current methods
#
# Before creating and running an algorithm to search for the most optimal masks, we first need to get a baseline by evaluating the metrics for the current methods that are used.
# For the baseline, the following mask collections were chosen:
#
# - [Corporate Masks](https://github.com/golem445/Corporate_Masks): Collection of masks with 8-14 characters created based on 1.5 million NTLM hashes. The masks are divided based on their length. We are considering they are ordered based on their priority.
# - [Extreme Breach Masks](https://github.com/sean-t-smith/Extreme_Breach_Masks): Collection of masks with 8-16 characters created based on terabytes of password breach datasets. These masks were created considering the frequency of the passwords present in the databases and divided according to their runtime. When calculating their baseline, we are considering the last set of masks that isn´t compressed (1-year) because they include all masks in the previous sets.

# %% [markdown]
# ### Step 2.1: Deciding fitness function
#
# In order to evaluate the baseline, we need to define a metric for their fitness.
# The first obvious parameter for our metric should be the percentage of passwords that it recovers in our dataset.
# Considering that time is a limited resource in a real world scenario, it makes sense to impose a penalty for masks that are very costly.
#
# With these considerations, it was decided to use the following fitness function:
# - We first decide on a desired maximum cost for our masks
# - Next, we calculate the match ratio for the masks by calculating how the percentage of the passwords they recover in the dataset.
# - If the masks don't go above the maximum cost, their fitness is the previously calculated match ratio.
# - If they go over the maximum cost, their fitness is calculated by first scaling their match ratio considering their cost.
# This way, if a mask has double the maximum cost, their match ratio will be halved. Lastly, we calculate their fitness by applying a penalty percentage to their fitness.
#
# With this fitness function, we aim to prioritize masks that recover as many passwords as possible, while keeping their cost as low as possible. An optimal mask can have a larger cost than the maximum, but suffers a penalty from doing so.

# %%
from utils.Mask import Mask, MaskCharset
from utils.WordlistTree import WordlistTree
from utils.MaskIndividual import MaskIndividual

def fitness_function_template(individual: MaskIndividual, wordlist_tree: WordlistTree, max_cost: int, cost_penalty: float) -> float:
    matches = individual.get_matches(wordlist_tree)
    match_ratio = matches / wordlist_tree.wordlist_len
    
    if individual.cost <= max_cost:
        return match_ratio
    
    scaled_match_ratio = match_ratio * (max_cost / individual.cost)
    
    return scaled_match_ratio * ( 1 - cost_penalty )

# %% [markdown]
# ### Step 2.2 Choosing the parameters
#
# The previously created fitness function depends on the following parameters:
#
# - max_cost: The maximum desired cost for our masks
# - cost_penalty: Percentage penalty that is applied to masks that go above the desired maximum cost
#
# To decide the maximum cost, we chose a desired run time of around 10 hours on an RTX 3070 Ti, benchmarked at a speed of 76146.5 MH/s with NTLM hashes.
# For the cost penalty, we decided on a 5% penalty to not discourage too much more costly masks, since they can be useful when your available time is larger than the previously stipulated one.
#
# Thus, we have decided on the following parameters:
#
# - max_cost: $5 * 10^{15}$
# - cost_penalty: 5%

# %%
max_cost = 5 * 10**15
cost_penalty = 0.05

# %% [markdown]
# ### Step 2.3: Calculating the baseline fitness
#
# Now it's time to calculate the baseline fitness for the chosen mask collections.
# In this step, for each collection we'll start with a single mask and continously add the next mask, calculating the total fitness of the set, until the fitness goes down, indicating our mask is too costly.
# Then, we'll return the set with the maximum fitness found.
# This is done because the masks are ordered to their priority (or at least we assume they are, since that's the order hashcat will use them).

# %%
import cloudpickle
import os
import json

corporate_masks_files = "baseline/Corporate_Masks/corp_{len}.hcmask"
extreme_breach_masks_files = "baseline/Extreme_Breach_Masks/14 1-year/1-year_{len}.hcmask"
wordlist_folder = "wordlists/trees"
output_file = "results/baseline.json"

min_len = 8
max_len = 15

def get_best_result_mask_file(mask_file: str, wordlist_tree: WordlistTree, max_cost: int, cost_penalty: float) -> dict:
    
    last_fitness = 0
    
    if not os.path.exists(mask_file):
        return {
            "fitness": 0,
            "masks": [],
            "cost": 0
        }
    
    with open(mask_file, "r") as f:
        masks = []
        for line in f:
            new_mask = Mask.from_str(line.strip())
            masks.append(new_mask)
            
            individual = MaskIndividual(masks, 0)
        
            fitness = fitness_function_template(individual, wordlist_tree, max_cost, cost_penalty)
            
            if fitness >= last_fitness:
                last_fitness = fitness            
            else:
                masks.pop()
                break
                
    return {
            "fitness": last_fitness,
            "masks": [str(mask) for mask in masks],
            "cost": MaskIndividual(masks, 0).cost
        }

best_results = {
    "corporate": {},
    "extreme_breach": {}
}

if not os.path.exists(output_file): 
    for len in range(min_len, max_len + 1):
        corporate_masks_file = corporate_masks_files.format(len=len)
        extreme_breach_masks_file = extreme_breach_masks_files.format(len=len)
        
        with open(os.path.join(wordlist_folder, f"{len}.pkl"), "rb") as f:
            wordlist_tree = cloudpickle.load(f)
            
            print(f"Processing word length: {len}")

            best_result = get_best_result_mask_file(corporate_masks_file, wordlist_tree, max_cost, cost_penalty)        
            print(f"Corporate Masks Best fitness: {best_result['fitness']}. Cost: {best_result['cost']}")
            best_results["corporate"][len] = best_result
        
            best_result = get_best_result_mask_file(extreme_breach_masks_file, wordlist_tree, max_cost, cost_penalty)
            print(f"Extreme Breach Masks Best fitness: {best_result['fitness']}. Cost: {best_result['cost']}")
            best_results["extreme_breach"][len] = best_result
            
    with open(output_file, "w") as f:
        json.dump(best_results, f)
# Out:
# Processing word length: 8
# Corporate Masks Best fitness: 0.9720793376298054. Cost: 1605171098613760
# Extreme Breach Masks Best fitness: 0.9997047772466525. Cost: 4999855044508416
# Processing word length: 9
# Corporate Masks Best fitness: 0.5622941244056113. Cost: 4999603084300800
# Extreme Breach Masks Best fitness: 0.9559869870321556. Cost: 4997928685184000
# Processing word length: 10
# Corporate Masks Best fitness: 0.3869147685368694. Cost: 4998028389760000
# Extreme Breach Masks Best fitness: 0.8467867662609967. Cost: 4988401456221184
# Processing word length: 11
# Corporate Masks Best fitness: 0.20811756818543767. Cost: 4989306592000000
# Extreme Breach Masks Best fitness: 0.444392950532486. Cost: 2834403868825600
# Processing word length: 12
# Corporate Masks Best fitness: 0.08592738299737888. Cost: 4986552000000000
# Extreme Breach Masks Best fitness: 0.17558914878961016. Cost: 4411987691520000
# Processing word length: 13
# Corporate Masks Best fitness: 0.03263954859553724. Cost: 4863360000000000
# Extreme Breach Masks Best fitness: 0.06571955084237449. Cost: 4394348800000000
# Processing word length: 14
# Corporate Masks Best fitness: 0.030719365855620972. Cost: 4940000000000000
# Extreme Breach Masks Best fitness: 0.03477967216815802. Cost: 1857600000000000
# Processing word length: 15
# Corporate Masks Best fitness: 0. Cost: 0
# Extreme Breach Masks Best fitness: 0.18758244533572602. Cost: 3600000000000000

# %% [markdown]
# ### Step 2.4: Analyzing baseline results
#
# Now that we calculated the fitness for the baseline collections, we can analyze their results:

# %%
import pandas as pd

with open("results/baseline.json", "r") as f:
    best_results = json.load(f)

corporate_results = [
    {
        "length": length,
        "fitness": result["fitness"],
        "cost": result["cost"]
    }
    for length, result in best_results["corporate"].items()
]

extreme_breach_results = [
    {
        "length": length,
        "fitness": result["fitness"],
        "cost": result["cost"]
    }
    for length, result in best_results["extreme_breach"].items()
]

results_df = pd.DataFrame(corporate_results).merge(pd.DataFrame(extreme_breach_results), on="length", suffixes=("_corporate", "_extreme_breach"))

results_df
# Out:
#   length  fitness_corporate    cost_corporate  fitness_extreme_breach  \
# 0      8           0.972079  1605171098613760                0.999705
# 1      9           0.562294  4999603084300800                0.955987
# 2     10           0.386915  4998028389760000                0.846787
# 3     11           0.208118  4989306592000000                0.444393
# 4     12           0.085927  4986552000000000                0.175589
# 5     13           0.032640  4863360000000000                0.065720
# 6     14           0.030719  4940000000000000                0.034780
# 7     15           0.000000                 0                0.187582
#
#    cost_extreme_breach
# 0     4999855044508416
# 1     4997928685184000
# 2     4988401456221184
# 3     2834403868825600
# 4     4411987691520000
# 5     4394348800000000
# 6     1857600000000000
# 7     3600000000000000

# %% [markdown]
# We can see that, in most cases, the Extreme Breach Masks significantly outperform the Corporate Masks.
# This could indicate that the Corporate Masks aren't properly sorted by their priority, however this would also represent an issue when using them in hahscat.
# At the same time, we can see that the Corporate Masks best fitness happens with a cost very close to the maximum cost, while the Extreme Breachs often achieves its best fitness at a lower cost than was allowed.

# %% [markdown]
# ## Step 3: Preparing the Genetic Algorithm
#
# Now that we have the wordlists prepared and our baseline results, we can focus on preparing the genetic algorithm for execution.
# We are using a simple custom made GeneticAlgorithm class defined in scripts/utils/GeneticAlgorithm.py.
#
# Our individuals are defined in scripts/utils/MaskIndividual.py and can hold a list of masks, up to **max_masks** (defined during creation).
# They also define functions for crossover and mutation, as described below:
#
# - Crossover: A number between **1** and **max_masks** is chosen from the parents in order to create the children, following a normal distribution centered around the average number of masks in the parents.
# - Mutation: Randomly chooses between one of the following mutation methods, making sure to keep the number of masks between **1** and **max_masks**:
#     - Insertion mutation: Insert a randomly created new mask in the individual
#     - Deletion mutation: Randomly removes one of the masks from the individual
#     - Mask mutation: Randomly changes one of the characters in one of the masks of the individual
#
# We just need to create helper functions that call the already implemented genetic operators described above:

# %%
from utils.MaskIndividual import MaskIndividual
    
def crossover_function(parent1: MaskIndividual, parent2: MaskIndividual) -> list[MaskIndividual]:
    return MaskIndividual.crossover(parent1, parent2)

def mutation_function(individual: MaskIndividual) -> MaskIndividual:
    return MaskIndividual.mutate(individual)

# %% [markdown]
# ## Step 3.1: Creating a Runner for the algorithm
#
# In this step, we create a Runner class that will help with loading the wordlist tree and running the genetic algorithm.

# %%
import os
import numpy as np
import cloudpickle

from utils.GeneticAlgorithm import GeneticAlgorithm
from utils.MaskIndividual import MaskIndividual


class Runner:
    def __init__(self, word_length: int, wordlist_folder: str, max_masks: int, max_cost: int, cost_penalty: float):
        self.max_masks = max_masks
        self.max_cost = max_cost
        self.cost_penalty = cost_penalty
        
        self.load_wordlist(wordlist_folder, word_length)
        
        self.fitness_function = lambda individual: fitness_function_template(individual, self.wordlist_tree, self.max_cost, self.cost_penalty)
        
    def load_wordlist(self, wordlist_folder: str, word_length: int):
        with open(os.path.join(wordlist_folder, f"{word_length}.pkl"), "rb") as f:
            self.wordlist_tree = cloudpickle.load(f)
        
    def run(self, 
            population_size: int, n_generations: int, 
            crossover_rate: float, mutation_rate: float, 
            elitism: int, tournament_size: int, 
            verbose: bool=False, seed: int=np.random.randint(10000000)) -> GeneticAlgorithm:        
        ga = GeneticAlgorithm(population_size, n_generations, crossover_rate, mutation_rate, elitism, tournament_size, self.fitness_function, crossover_function, mutation_function)
        
        np.random.seed(seed)
        
        individuals = [ MaskIndividual.generate_random(self.max_masks, self.wordlist_tree.word_len) for _ in range(population_size) ]
        
        ga.run(individuals, verbose)
        
        return ga

# %% [markdown]
# ### Step 3.2: Test Run
#
# In this step, we do a test run to check if the previous steps were done correctly.

# %%
import cloudpickle

outfolder = "results"

wordlist_folder = r"wordlists/trees"
word_length = 8
max_masks = 10

runner = Runner(word_length, wordlist_folder, max_masks, max_cost, cost_penalty)

population_size = 30
n_generations = 30

crossover_rate = 1.0
mutation_rate = 0.1
elitism = 1
tournament_size = 3

seed = 23

ga = runner.run(population_size, n_generations, crossover_rate, mutation_rate, elitism, tournament_size, verbose=False, seed=seed)

with open(os.path.join(outfolder, f"ga_{word_length}_{seed}.pkl"), "wb") as f:
    cloudpickle.dump(ga, f)

# %%
import cloudpickle
import matplotlib.pyplot as plt

outfolder = "results"

with open(os.path.join(outfolder, f"ga_{word_length}_{seed}.pkl"), "rb") as f:
    ga = cloudpickle.load(f)

plt.plot(ga.run_stats["max_fitness"], label="Max Fitness")
plt.plot(ga.run_stats["min_fitness"], label="Min Fitness")
plt.plot(ga.run_stats["avg_fitness"], label="Avg Fitness")

plt.legend()
plt.show()

best_individual = ga.run_stats["best_individual"][-1]
max_fitness = ga.run_stats["max_fitness"][-1]
best_individual = ga.run_stats["best_individual"][-1]
max_fitness = ga.run_stats["max_fitness"][-1]
best_individual_matches = best_individual.get_matches(runner.wordlist_tree)

print("Best individual:")
print(best_individual)
print(f"Cost: {best_individual.cost}, fitness: {max_fitness}, matches: {best_individual_matches}/{runner.wordlist_tree.wordlist_len} ({best_individual_matches / runner.wordlist_tree.wordlist_len * 100:.2f}%)")
# Out:
# Best individual:
# ?u?a?u?a?l?l?a?l
# ?u?a?l?a?l?l?a?l
# ?u?s?s?u?d?u?s?a
# ?d?a?u?a?l?l?a?l
# ?a?d?a?d?l?a?a?l
# ?d?l?s?a?a?d?a?a
# ?a?u?a?d?l?a?a?l
# ?l?a?l?a?d?d?l?l
# ?a?s?l?l?u?s?l?l
# ?d?l?s?a?a?d?a?a
# Cost: 63155809886208, fitness: 0.034360838376964374, matches: 15360625/447038714 (3.44%)

# %% [markdown]
# We can see that the Genetic Algorithm is working properly and we can evolve an individual to improve their fitness.

# %% [markdown]
# ### Step 3.3: Optimizing Parameters
#
# Our next step is finding the best parameters for the Genetic Algorithm.
# The parameters we have to choose are as follows:
#
# - population_size: Number of individuals in each generation
# - n_generations: Number of generations
# - crossover_rate: Chance for a crossover between individuals
# - mutation_rate: Chance for a mutation between individuals
# - elitism: Number of individuals selected for elitism
# - tournament_size: Number of individuals chosen for the tournament
# - max_masks: Maximum number of masks available for each individual
#
# For optimizing the parameters, we are running our tests on the wordlist tree of size 10, because it offers a greater degree of complexity compared to size 8.

# %%
# %%script echo skipping
#
# import optuna
#
# wordlist_folder = r"wordlists/trees"
# word_length = 10
#
# def objective(trial):
#     population_size = trial.suggest_int("population_size", 10, 300)
#     n_generations = trial.suggest_int("n_generations", 10, 300)
#     crossover_rate = trial.suggest_float("crossover_rate", 0.5, 1.0)
#     mutation_rate = trial.suggest_float("mutation_rate", 0.01, 0.5)
#     elitism = trial.suggest_int("elitism", 1, 5)
#     tournament_size = trial.suggest_int("tournament_size", 3, 5)
#     max_masks = trial.suggest_int("max_masks", 5, 30)
#
#     runner = Runner(word_length, wordlist_folder, max_masks, max_cost, cost_penalty)
#
#     ga = runner.run(population_size, n_generations, crossover_rate, mutation_rate, elitism, tournament_size, verbose=False)
#
#     return ga.run_stats["max_fitness"][-1]
#
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=500, n_jobs=20)
#
# study.best_params
# Out:
# [I 2025-01-26 20:20:17,453] A new study created in memory with name: no-name-7ef4650b-29fc-4005-b740-7759d5f67f04
# [I 2025-01-26 20:21:59,030] Trial 0 finished with value: 0.02525660293320522 and parameters: {'population_size': 20, 'n_generations': 80, 'crossover_rate': 0.8441875125566787, 'mutation_rate': 0.3328675789002472, 'elitism': 1, 'tournament_size': 3, 'max_masks': 25}. Best is trial 0 with value: 0.02525660293320522.
# [I 2025-01-26 20:22:48,762] Trial 2 finished with value: 0.07370770069472943 and parameters: {'population_size': 17, 'n_generations': 139, 'crossover_rate': 0.5244073283343736, 'mutation_rate': 0.012928001741092498, 'elitism': 1, 'tournament_size': 4, 'max_masks': 15}. Best is trial 2 with value: 0.07370770069472943.
# [I 2025-01-26 20:23:19,560] Trial 9 finished with value: 0.1553048516208512 and parameters: {'population_size': 127, 'n_generations': 44, 'crossover_rate': 0.8232509036333584, 'mutation_rate': 0.3347225798216875, 'elitism': 3, 'tournament_size': 4, 'max_masks': 20}. Best is trial 9 with value: 0.1553048516208512.
# [I 2025-01-26 20:24:09,537] Trial 18 finished with value: 0.3677071345278241 and parameters: {'population_size': 37, 'n_generations': 203, 'crossover_rate': 0.8445770997916745, 'mutation_rate': 0.34200499444850274, 'elitism': 4, 'tournament_size': 5, 'max_masks': 8}. Best is trial 18 with value: 0.3677071345278241.
# [I 2025-01-26 20:24:19,744] Trial 11 finished with value: 0.24067591115443734 and parameters: {'population_size': 40, 'n_generations': 157, 'crossover_rate': 0.9805602643056569, 'mutation_rate': 0.1041826389003282, 'elitism': 3, 'tournament_size': 5, 'max_masks': 28}. Best is trial 18 with value: 0.3677071345278241.
# [I 2025-01-26 20:24:28,856] Trial 19 finished with value: 0.27791591441013047 and parameters: {'population_size': 51, 'n_generations': 103, 'crossover_rate': 0.9318804651252683, 'mutation_rate': 0.44173077978798203, 'elitism': 5, 'tournament_size': 3, 'max_masks': 20}. Best is trial 18 with value: 0.3677071345278241.
# [I 2025-01-26 20:24:55,781] Trial 21 finished with value: 0.4045621754130738 and parameters: {'population_size': 132, 'n_generations': 75, 'crossover_rate': 0.8453672564056064, 'mutation_rate': 0.25595831115424444, 'elitism': 5, 'tournament_size': 4, 'max_masks': 5}. Best is trial 21 with value: 0.4045621754130738.
# [I 2025-01-26 20:24:56,032] Trial 4 finished with value: 0.2932786152783828 and parameters: {'population_size': 282, 'n_generations': 27, 'crossover_rate': 0.5670878651316715, 'mutation_rate': 0.09319126028244243, 'elitism': 3, 'tournament_size': 5, 'max_masks': 18}. Best is trial 21 with value: 0.4045621754130738.
# [I 2025-01-26 20:25:08,313] Trial 13 finished with value: 0.3539455094700675 and parameters: {'population_size': 197, 'n_generations': 66, 'crossover_rate': 0.5780138225247597, 'mutation_rate': 0.3058273189221266, 'elitism': 1, 'tournament_size': 5, 'max_masks': 20}. Best is trial 21 with value: 0.4045621754130738.
# [I 2025-01-26 20:26:10,632] Trial 12 finished with value: 0.13435606918316806 and parameters: {'population_size': 64, 'n_generations': 227, 'crossover_rate': 0.9090879583290036, 'mutation_rate': 0.017032275878091467, 'elitism': 3, 'tournament_size': 4, 'max_masks': 17}. Best is trial 21 with value: 0.4045621754130738.
# [I 2025-01-26 20:26:57,406] Trial 17 finished with value: 0.27907749654627295 and parameters: {'population_size': 164, 'n_generations': 69, 'crossover_rate': 0.9922922225108827, 'mutation_rate': 0.41385810180461535, 'elitism': 3, 'tournament_size': 3, 'max_masks': 22}. Best is trial 21 with value: 0.4045621754130738.
# [I 2025-01-26 20:28:13,539] Trial 8 finished with value: 0.5790399160118319 and parameters: {'population_size': 279, 'n_generations': 63, 'crossover_rate': 0.6720551900462072, 'mutation_rate': 0.45132967818169123, 'elitism': 5, 'tournament_size': 4, 'max_masks': 24}. Best is trial 8 with value: 0.5790399160118319.
# [I 2025-01-26 20:29:10,135] Trial 24 finished with value: 0.25955566324865575 and parameters: {'population_size': 73, 'n_generations': 86, 'crossover_rate': 0.5635268740947248, 'mutation_rate': 0.3136117176870479, 'elitism': 2, 'tournament_size': 4, 'max_masks': 27}. Best is trial 8 with value: 0.5790399160118319.
# [I 2025-01-26 20:29:28,516] Trial 5 finished with value: 0.649165797107133 and parameters: {'population_size': 114, 'n_generations': 250, 'crossover_rate': 0.7124115037271421, 'mutation_rate': 0.3070815456637135, 'elitism': 4, 'tournament_size': 5, 'max_masks': 21}. Best is trial 5 with value: 0.649165797107133.
# [I 2025-01-26 20:30:33,861] Trial 14 finished with value: 0.4317118970583385 and parameters: {'population_size': 288, 'n_generations': 142, 'crossover_rate': 0.8728521057999672, 'mutation_rate': 0.38555083416927965, 'elitism': 2, 'tournament_size': 5, 'max_masks': 27}. Best is trial 5 with value: 0.649165797107133.
# [I 2025-01-26 20:31:30,995] Trial 32 finished with value: 0.09870090373497413 and parameters: {'population_size': 284, 'n_generations': 11, 'crossover_rate': 0.6841642376966272, 'mutation_rate': 0.20650449007109634, 'elitism': 5, 'tournament_size': 4, 'max_masks': 5}. Best is trial 5 with value: 0.649165797107133.
# [I 2025-01-26 20:31:44,691] Trial 23 finished with value: 0.565603054126521 and parameters: {'population_size': 282, 'n_generations': 241, 'crossover_rate': 0.7280533578043465, 'mutation_rate': 0.05637017511709132, 'elitism': 3, 'tournament_size': 3, 'max_masks': 14}. Best is trial 5 with value: 0.649165797107133.
# [I 2025-01-26 20:32:05,634] Trial 16 finished with value: 0.6617913315458146 and parameters: {'population_size': 228, 'n_generations': 99, 'crossover_rate': 0.5658795846992721, 'mutation_rate': 0.2655485482732747, 'elitism': 5, 'tournament_size': 3, 'max_masks': 24}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:32:06,868] Trial 27 finished with value: 0.431233859457703 and parameters: {'population_size': 147, 'n_generations': 155, 'crossover_rate': 0.6278411964061617, 'mutation_rate': 0.3258252586992525, 'elitism': 2, 'tournament_size': 3, 'max_masks': 11}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:32:17,605] Trial 28 finished with value: 0.40400870446601106 and parameters: {'population_size': 115, 'n_generations': 106, 'crossover_rate': 0.8098827839853471, 'mutation_rate': 0.13501270059265794, 'elitism': 3, 'tournament_size': 5, 'max_masks': 22}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:32:21,384] Trial 1 finished with value: 0.4614032659955768 and parameters: {'population_size': 159, 'n_generations': 190, 'crossover_rate': 0.5845690972595784, 'mutation_rate': 0.27147578761590113, 'elitism': 3, 'tournament_size': 5, 'max_masks': 10}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:32:33,059] Trial 6 finished with value: 0.09875047057371632 and parameters: {'population_size': 106, 'n_generations': 134, 'crossover_rate': 0.83018734773516, 'mutation_rate': 0.06700169191184051, 'elitism': 4, 'tournament_size': 3, 'max_masks': 17}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:36:05,018] Trial 30 finished with value: 0.474621047726877 and parameters: {'population_size': 107, 'n_generations': 287, 'crossover_rate': 0.7211203122435226, 'mutation_rate': 0.20638752077640196, 'elitism': 5, 'tournament_size': 4, 'max_masks': 5}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:38:11,665] Trial 31 finished with value: 0.6572758999182498 and parameters: {'population_size': 295, 'n_generations': 294, 'crossover_rate': 0.6889948521814154, 'mutation_rate': 0.1974032928056101, 'elitism': 5, 'tournament_size': 4, 'max_masks': 5}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:41:31,803] Trial 26 finished with value: 0.6613131274932237 and parameters: {'population_size': 162, 'n_generations': 253, 'crossover_rate': 0.7006249399396646, 'mutation_rate': 0.44084228150679444, 'elitism': 3, 'tournament_size': 4, 'max_masks': 15}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:44:41,800] Trial 7 finished with value: 0.4094667713094999 and parameters: {'population_size': 296, 'n_generations': 128, 'crossover_rate': 0.7760640205076608, 'mutation_rate': 0.4220266693254265, 'elitism': 1, 'tournament_size': 3, 'max_masks': 25}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:46:05,420] Trial 38 finished with value: 0.4684852109516413 and parameters: {'population_size': 233, 'n_generations': 297, 'crossover_rate': 0.7749710490514603, 'mutation_rate': 0.1960200230285432, 'elitism': 4, 'tournament_size': 3, 'max_masks': 30}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:47:08,032] Trial 29 finished with value: 0.5816465123387191 and parameters: {'population_size': 166, 'n_generations': 299, 'crossover_rate': 0.6960951175327607, 'mutation_rate': 0.1866337314993093, 'elitism': 5, 'tournament_size': 4, 'max_masks': 6}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:48:49,608] Trial 36 finished with value: 0.6591348415658639 and parameters: {'population_size': 225, 'n_generations': 263, 'crossover_rate': 0.6610482787721562, 'mutation_rate': 0.4958973078982538, 'elitism': 4, 'tournament_size': 5, 'max_masks': 24}. Best is trial 16 with value: 0.6617913315458146.
# [I 2025-01-26 20:51:58,993] Trial 25 finished with value: 0.6758922209943341 and parameters: {'population_size': 267, 'n_generations': 214, 'crossover_rate': 0.7220921274435506, 'mutation_rate': 0.3415821694539472, 'elitism': 3, 'tournament_size': 3, 'max_masks': 17}. Best is trial 25 with value: 0.6758922209943341.
# [I 2025-01-26 20:53:02,640] Trial 10 finished with value: 0.697201990081341 and parameters: {'population_size': 299, 'n_generations': 246, 'crossover_rate': 0.5187231603667974, 'mutation_rate': 0.32539315470195007, 'elitism': 1, 'tournament_size': 4, 'max_masks': 12}. Best is trial 10 with value: 0.697201990081341.
# [I 2025-01-26 20:56:26,458] Trial 22 finished with value: 0.24635468037792807 and parameters: {'population_size': 221, 'n_generations': 165, 'crossover_rate': 0.9672913600545209, 'mutation_rate': 0.11122874309808008, 'elitism': 3, 'tournament_size': 3, 'max_masks': 30}. Best is trial 10 with value: 0.697201990081341.
# [I 2025-01-26 20:57:44,712] Trial 34 finished with value: 0.7006350189015397 and parameters: {'population_size': 235, 'n_generations': 277, 'crossover_rate': 0.6810617353293582, 'mutation_rate': 0.4964985385770721, 'elitism': 4, 'tournament_size': 4, 'max_masks': 12}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:00:25,940] Trial 35 finished with value: 0.6517791756093181 and parameters: {'population_size': 231, 'n_generations': 298, 'crossover_rate': 0.7032252896463539, 'mutation_rate': 0.4966634168910834, 'elitism': 4, 'tournament_size': 4, 'max_masks': 14}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:01:58,705] Trial 46 finished with value: 0.6935572571687889 and parameters: {'population_size': 242, 'n_generations': 272, 'crossover_rate': 0.637659534162765, 'mutation_rate': 0.49339069331619206, 'elitism': 4, 'tournament_size': 4, 'max_masks': 13}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:03:11,315] Trial 43 finished with value: 0.6238721614425398 and parameters: {'population_size': 228, 'n_generations': 278, 'crossover_rate': 0.7701240550285559, 'mutation_rate': 0.19263087491436992, 'elitism': 4, 'tournament_size': 3, 'max_masks': 30}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:06:06,294] Trial 39 finished with value: 0.4804098562841803 and parameters: {'population_size': 235, 'n_generations': 300, 'crossover_rate': 0.6771022583759929, 'mutation_rate': 0.19626104149858337, 'elitism': 4, 'tournament_size': 4, 'max_masks': 24}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:06:26,588] Trial 37 finished with value: 0.630110741810928 and parameters: {'population_size': 202, 'n_generations': 293, 'crossover_rate': 0.6490549823620257, 'mutation_rate': 0.19483241627489223, 'elitism': 4, 'tournament_size': 3, 'max_masks': 12}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:08:10,907] Trial 3 finished with value: 0.41498655625945136 and parameters: {'population_size': 258, 'n_generations': 260, 'crossover_rate': 0.7754408669370574, 'mutation_rate': 0.43033766344757923, 'elitism': 1, 'tournament_size': 4, 'max_masks': 10}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:08:44,247] Trial 49 finished with value: 0.4537932046587537 and parameters: {'population_size': 240, 'n_generations': 192, 'crossover_rate': 0.5317476475891544, 'mutation_rate': 0.3697711256630593, 'elitism': 2, 'tournament_size': 3, 'max_masks': 13}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:08:44,621] Trial 52 finished with value: 0.6567985735955505 and parameters: {'population_size': 254, 'n_generations': 203, 'crossover_rate': 0.5146055717295923, 'mutation_rate': 0.36808790336792496, 'elitism': 2, 'tournament_size': 3, 'max_masks': 11}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:11:34,612] Trial 50 finished with value: 0.6857659539468821 and parameters: {'population_size': 258, 'n_generations': 206, 'crossover_rate': 0.5030689858454025, 'mutation_rate': 0.37235466607583084, 'elitism': 2, 'tournament_size': 3, 'max_masks': 13}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:12:27,919] Trial 40 finished with value: 0.6454800754536455 and parameters: {'population_size': 236, 'n_generations': 272, 'crossover_rate': 0.6694935354336615, 'mutation_rate': 0.494288781558646, 'elitism': 4, 'tournament_size': 4, 'max_masks': 24}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:13:06,984] Trial 47 finished with value: 0.5013457404499797 and parameters: {'population_size': 250, 'n_generations': 265, 'crossover_rate': 0.6533848709867324, 'mutation_rate': 0.15388067703162292, 'elitism': 4, 'tournament_size': 4, 'max_masks': 13}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:18:24,856] Trial 55 finished with value: 0.40983872646995245 and parameters: {'population_size': 259, 'n_generations': 215, 'crossover_rate': 0.5001864674462193, 'mutation_rate': 0.3700988388395492, 'elitism': 2, 'tournament_size': 4, 'max_masks': 11}. Best is trial 34 with value: 0.7006350189015397.
# [I 2025-01-26 21:20:37,888] Trial 33 finished with value: 0.7025493851455421 and parameters: {'population_size': 293, 'n_generations': 292, 'crossover_rate': 0.6793817821144168, 'mutation_rate': 0.48748405734653555, 'elitism': 4, 'tournament_size': 5, 'max_masks': 13}. Best is trial 33 with value: 0.7025493851455421.
# [I 2025-01-26 21:21:28,942] Trial 20 finished with value: 0.6302263780553832 and parameters: {'population_size': 273, 'n_generations': 264, 'crossover_rate': 0.8206012501109486, 'mutation_rate': 0.3282173536103422, 'elitism': 2, 'tournament_size': 4, 'max_masks': 8}. Best is trial 33 with value: 0.7025493851455421.
# [I 2025-01-26 21:22:10,275] Trial 45 finished with value: 0.7080085475951368 and parameters: {'population_size': 239, 'n_generations': 288, 'crossover_rate': 0.6434295526200962, 'mutation_rate': 0.48787672434016943, 'elitism': 4, 'tournament_size': 4, 'max_masks': 30}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:22:53,004] Trial 56 finished with value: 0.6929351427641676 and parameters: {'population_size': 253, 'n_generations': 213, 'crossover_rate': 0.510884664542623, 'mutation_rate': 0.3748104520233626, 'elitism': 2, 'tournament_size': 4, 'max_masks': 11}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:23:25,522] Trial 53 finished with value: 0.6232331554062792 and parameters: {'population_size': 257, 'n_generations': 199, 'crossover_rate': 0.520528069453958, 'mutation_rate': 0.36939474347620416, 'elitism': 2, 'tournament_size': 3, 'max_masks': 12}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:26:21,197] Trial 61 finished with value: 0.6832287760943728 and parameters: {'population_size': 265, 'n_generations': 233, 'crossover_rate': 0.6199703051212084, 'mutation_rate': 0.47091355421280995, 'elitism': 1, 'tournament_size': 4, 'max_masks': 8}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:27:45,547] Trial 41 finished with value: 0.6208751153771274 and parameters: {'population_size': 240, 'n_generations': 300, 'crossover_rate': 0.6619518955284602, 'mutation_rate': 0.20043590635069897, 'elitism': 4, 'tournament_size': 4, 'max_masks': 30}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:29:24,888] Trial 57 finished with value: 0.6668983251077281 and parameters: {'population_size': 260, 'n_generations': 210, 'crossover_rate': 0.6291224193162164, 'mutation_rate': 0.37298866971402267, 'elitism': 2, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:30:38,505] Trial 58 finished with value: 0.694334686188998 and parameters: {'population_size': 261, 'n_generations': 214, 'crossover_rate': 0.5137955692038063, 'mutation_rate': 0.3702911414993997, 'elitism': 2, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:31:48,467] Trial 60 finished with value: 0.6666005225605373 and parameters: {'population_size': 265, 'n_generations': 229, 'crossover_rate': 0.6143271477842122, 'mutation_rate': 0.28691099167819567, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:32:41,815] Trial 62 finished with value: 0.5189488966670698 and parameters: {'population_size': 262, 'n_generations': 232, 'crossover_rate': 0.6008555953728489, 'mutation_rate': 0.2869163868696645, 'elitism': 1, 'tournament_size': 4, 'max_masks': 8}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:36:47,974] Trial 66 finished with value: 0.693321013989676 and parameters: {'population_size': 204, 'n_generations': 236, 'crossover_rate': 0.6200872245187863, 'mutation_rate': 0.4617642975303486, 'elitism': 1, 'tournament_size': 5, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:37:26,184] Trial 54 finished with value: 0.6896021129012755 and parameters: {'population_size': 255, 'n_generations': 273, 'crossover_rate': 0.5111782859295799, 'mutation_rate': 0.3730730486828813, 'elitism': 2, 'tournament_size': 4, 'max_masks': 12}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:37:30,708] Trial 65 finished with value: 0.6909188820397945 and parameters: {'population_size': 270, 'n_generations': 239, 'crossover_rate': 0.6228877041664048, 'mutation_rate': 0.4626706765138321, 'elitism': 1, 'tournament_size': 5, 'max_masks': 8}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:38:31,040] Trial 63 finished with value: 0.6368423324769242 and parameters: {'population_size': 265, 'n_generations': 233, 'crossover_rate': 0.613644066910913, 'mutation_rate': 0.465857005503843, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:38:44,781] Trial 48 finished with value: 0.467883679624232 and parameters: {'population_size': 233, 'n_generations': 260, 'crossover_rate': 0.6378167071529218, 'mutation_rate': 0.4040875291158117, 'elitism': 4, 'tournament_size': 3, 'max_masks': 14}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:39:44,018] Trial 59 finished with value: 0.6796298781122645 and parameters: {'population_size': 258, 'n_generations': 231, 'crossover_rate': 0.6152733699793789, 'mutation_rate': 0.4704364660621046, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:40:06,260] Trial 70 finished with value: 0.6826449518781474 and parameters: {'population_size': 205, 'n_generations': 243, 'crossover_rate': 0.6043271083321734, 'mutation_rate': 0.46887702827188127, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:40:17,855] Trial 68 finished with value: 0.4725537784637766 and parameters: {'population_size': 209, 'n_generations': 246, 'crossover_rate': 0.6124290113265951, 'mutation_rate': 0.4590499488755393, 'elitism': 1, 'tournament_size': 4, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:44:12,810] Trial 67 finished with value: 0.486151199556404 and parameters: {'population_size': 207, 'n_generations': 241, 'crossover_rate': 0.6114137024475884, 'mutation_rate': 0.47089917980935847, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:44:21,877] Trial 44 finished with value: 0.6288990356954383 and parameters: {'population_size': 232, 'n_generations': 298, 'crossover_rate': 0.7746802630553001, 'mutation_rate': 0.4949871057374924, 'elitism': 4, 'tournament_size': 4, 'max_masks': 13}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:45:10,130] Trial 15 finished with value: 0.3615614783648141 and parameters: {'population_size': 270, 'n_generations': 279, 'crossover_rate': 0.7304077346584191, 'mutation_rate': 0.13539147032752635, 'elitism': 3, 'tournament_size': 3, 'max_masks': 13}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:45:39,853] Trial 64 finished with value: 0.6742997761944403 and parameters: {'population_size': 273, 'n_generations': 242, 'crossover_rate': 0.618504966904224, 'mutation_rate': 0.47159895483782566, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:45:50,028] Trial 69 finished with value: 0.689861164607503 and parameters: {'population_size': 191, 'n_generations': 246, 'crossover_rate': 0.6069075101104495, 'mutation_rate': 0.4733055304760595, 'elitism': 1, 'tournament_size': 5, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:45:58,572] Trial 78 finished with value: 0.5119144985259896 and parameters: {'population_size': 211, 'n_generations': 255, 'crossover_rate': 0.7446717291703057, 'mutation_rate': 0.4249802396614225, 'elitism': 4, 'tournament_size': 4, 'max_masks': 15}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:49:57,941] Trial 74 finished with value: 0.6802955646472187 and parameters: {'population_size': 211, 'n_generations': 277, 'crossover_rate': 0.5913215852647264, 'mutation_rate': 0.46928440015811096, 'elitism': 1, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:52:10,649] Trial 72 finished with value: 0.492484020725008 and parameters: {'population_size': 210, 'n_generations': 247, 'crossover_rate': 0.5978628318206097, 'mutation_rate': 0.4669835258532795, 'elitism': 1, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:53:33,095] Trial 75 finished with value: 0.4971837849673816 and parameters: {'population_size': 207, 'n_generations': 278, 'crossover_rate': 0.5408976097379731, 'mutation_rate': 0.40425299731781683, 'elitism': 4, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:55:16,296] Trial 83 finished with value: 0.6856583853473889 and parameters: {'population_size': 297, 'n_generations': 286, 'crossover_rate': 0.7349312110293886, 'mutation_rate': 0.4229341365573445, 'elitism': 4, 'tournament_size': 5, 'max_masks': 7}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:55:50,470] Trial 73 finished with value: 0.6835717755059514 and parameters: {'population_size': 202, 'n_generations': 281, 'crossover_rate': 0.5995655225251901, 'mutation_rate': 0.47174918163784696, 'elitism': 1, 'tournament_size': 5, 'max_masks': 15}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:58:35,804] Trial 90 finished with value: 0.6223314971782913 and parameters: {'population_size': 295, 'n_generations': 284, 'crossover_rate': 0.5453908648746315, 'mutation_rate': 0.40493857531863114, 'elitism': 3, 'tournament_size': 5, 'max_masks': 7}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 21:59:58,538] Trial 51 finished with value: 0.47662803565762124 and parameters: {'population_size': 254, 'n_generations': 207, 'crossover_rate': 0.5116845444188053, 'mutation_rate': 0.3769375864915765, 'elitism': 2, 'tournament_size': 3, 'max_masks': 12}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:00:08,109] Trial 71 finished with value: 0.6969268279853282 and parameters: {'population_size': 300, 'n_generations': 280, 'crossover_rate': 0.5996691258380605, 'mutation_rate': 0.46234361353154124, 'elitism': 1, 'tournament_size': 4, 'max_masks': 9}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:03:11,559] Trial 84 finished with value: 0.6891101857597041 and parameters: {'population_size': 297, 'n_generations': 254, 'crossover_rate': 0.5371544399728717, 'mutation_rate': 0.42790012035673053, 'elitism': 4, 'tournament_size': 5, 'max_masks': 18}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:05:31,207] Trial 77 finished with value: 0.5053334758866278 and parameters: {'population_size': 299, 'n_generations': 248, 'crossover_rate': 0.545132881785223, 'mutation_rate': 0.40156935848369574, 'elitism': 4, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:06:05,270] Trial 76 finished with value: 0.484591087586705 and parameters: {'population_size': 295, 'n_generations': 278, 'crossover_rate': 0.5840276659211034, 'mutation_rate': 0.3979621798945565, 'elitism': 4, 'tournament_size': 5, 'max_masks': 18}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:07:05,333] Trial 80 finished with value: 0.4935518351635714 and parameters: {'population_size': 210, 'n_generations': 250, 'crossover_rate': 0.5563183563048306, 'mutation_rate': 0.4716291310295818, 'elitism': 1, 'tournament_size': 5, 'max_masks': 15}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:07:45,670] Trial 42 finished with value: 0.6866118832488518 and parameters: {'population_size': 242, 'n_generations': 271, 'crossover_rate': 0.6616635037022236, 'mutation_rate': 0.47309709776877784, 'elitism': 4, 'tournament_size': 4, 'max_masks': 30}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:07:48,536] Trial 94 finished with value: 0.6351844532248558 and parameters: {'population_size': 185, 'n_generations': 221, 'crossover_rate': 0.5492595976540859, 'mutation_rate': 0.43715128795553226, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:09:07,695] Trial 81 finished with value: 0.6744653029794416 and parameters: {'population_size': 216, 'n_generations': 249, 'crossover_rate': 0.5453041627568928, 'mutation_rate': 0.4272191099788647, 'elitism': 1, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:09:38,141] Trial 99 finished with value: 0.47200912216583896 and parameters: {'population_size': 287, 'n_generations': 175, 'crossover_rate': 0.5798737834688157, 'mutation_rate': 0.4440617500718946, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:10:57,729] Trial 79 finished with value: 0.6973315890786124 and parameters: {'population_size': 300, 'n_generations': 247, 'crossover_rate': 0.5486264659272309, 'mutation_rate': 0.4068533180941618, 'elitism': 4, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:12:16,862] Trial 88 finished with value: 0.6697294148607452 and parameters: {'population_size': 296, 'n_generations': 287, 'crossover_rate': 0.5425775464650326, 'mutation_rate': 0.42690262865147705, 'elitism': 3, 'tournament_size': 5, 'max_masks': 7}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:12:45,574] Trial 93 finished with value: 0.4592037620374663 and parameters: {'population_size': 180, 'n_generations': 180, 'crossover_rate': 0.5798949293640899, 'mutation_rate': 0.4462079533060273, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:12:49,442] Trial 96 finished with value: 0.6310760672783075 and parameters: {'population_size': 179, 'n_generations': 220, 'crossover_rate': 0.5560944821892148, 'mutation_rate': 0.4457326909020466, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:20:06,977] Trial 97 finished with value: 0.6653762263123812 and parameters: {'population_size': 287, 'n_generations': 268, 'crossover_rate': 0.5508109907361327, 'mutation_rate': 0.4411657762653637, 'elitism': 4, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:20:37,250] Trial 101 finished with value: 0.64291023795662 and parameters: {'population_size': 279, 'n_generations': 182, 'crossover_rate': 0.5719736261632415, 'mutation_rate': 0.4416022608695536, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:22:12,024] Trial 95 finished with value: 0.49200083975718006 and parameters: {'population_size': 185, 'n_generations': 221, 'crossover_rate': 0.5794196396531613, 'mutation_rate': 0.4425862337030004, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:22:25,668] Trial 85 finished with value: 0.7048871471241818 and parameters: {'population_size': 296, 'n_generations': 280, 'crossover_rate': 0.5530200338391458, 'mutation_rate': 0.435125551097042, 'elitism': 3, 'tournament_size': 5, 'max_masks': 19}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:23:54,361] Trial 92 finished with value: 0.4971563076642472 and parameters: {'population_size': 299, 'n_generations': 180, 'crossover_rate': 0.5575418251703729, 'mutation_rate': 0.4413445731301506, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:24:04,342] Trial 82 finished with value: 0.6836293850895168 and parameters: {'population_size': 213, 'n_generations': 281, 'crossover_rate': 0.5351495678736609, 'mutation_rate': 0.42744926384534254, 'elitism': 4, 'tournament_size': 5, 'max_masks': 16}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:24:45,693] Trial 105 finished with value: 0.6706536582116689 and parameters: {'population_size': 279, 'n_generations': 267, 'crossover_rate': 0.6466716375538678, 'mutation_rate': 0.3508400152935875, 'elitism': 5, 'tournament_size': 4, 'max_masks': 11}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:25:55,395] Trial 89 finished with value: 0.49717239937892826 and parameters: {'population_size': 292, 'n_generations': 283, 'crossover_rate': 0.5449136643772177, 'mutation_rate': 0.4046978626618275, 'elitism': 3, 'tournament_size': 5, 'max_masks': 18}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:26:21,966] Trial 87 finished with value: 0.48076281886378486 and parameters: {'population_size': 183, 'n_generations': 280, 'crossover_rate': 0.5485314825563082, 'mutation_rate': 0.4347168836753143, 'elitism': 3, 'tournament_size': 5, 'max_masks': 19}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:28:45,302] Trial 98 finished with value: 0.6960467139053425 and parameters: {'population_size': 285, 'n_generations': 263, 'crossover_rate': 0.5749309859962488, 'mutation_rate': 0.44541713308048403, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:28:57,589] Trial 103 finished with value: 0.39169883531157157 and parameters: {'population_size': 280, 'n_generations': 183, 'crossover_rate': 0.5725225662630664, 'mutation_rate': 0.448223484213581, 'elitism': 3, 'tournament_size': 4, 'max_masks': 11}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:30:03,565] Trial 86 finished with value: 0.7046305231814846 and parameters: {'population_size': 296, 'n_generations': 285, 'crossover_rate': 0.5830459230930746, 'mutation_rate': 0.43482465785052926, 'elitism': 4, 'tournament_size': 5, 'max_masks': 18}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:31:34,768] Trial 100 finished with value: 0.68119517864838 and parameters: {'population_size': 278, 'n_generations': 268, 'crossover_rate': 0.5596212268611409, 'mutation_rate': 0.44350927511439187, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:31:55,318] Trial 107 finished with value: 0.6951483853738453 and parameters: {'population_size': 277, 'n_generations': 267, 'crossover_rate': 0.6439402983997324, 'mutation_rate': 0.4870198229377358, 'elitism': 5, 'tournament_size': 4, 'max_masks': 14}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:34:08,312] Trial 91 finished with value: 0.6958215481754657 and parameters: {'population_size': 300, 'n_generations': 286, 'crossover_rate': 0.5345177114035667, 'mutation_rate': 0.4097815728264372, 'elitism': 3, 'tournament_size': 5, 'max_masks': 7}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:34:32,046] Trial 102 finished with value: 0.47789454075351245 and parameters: {'population_size': 287, 'n_generations': 183, 'crossover_rate': 0.6443089421876163, 'mutation_rate': 0.44129408255999414, 'elitism': 3, 'tournament_size': 4, 'max_masks': 10}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:35:59,905] Trial 106 finished with value: 0.6777914604040328 and parameters: {'population_size': 278, 'n_generations': 268, 'crossover_rate': 0.6411804139846149, 'mutation_rate': 0.4529823010511071, 'elitism': 4, 'tournament_size': 4, 'max_masks': 14}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:36:08,232] Trial 111 finished with value: 0.6332112884156618 and parameters: {'population_size': 247, 'n_generations': 260, 'crossover_rate': 0.6406681780282437, 'mutation_rate': 0.3488995411170422, 'elitism': 5, 'tournament_size': 4, 'max_masks': 11}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:38:42,290] Trial 110 finished with value: 0.70142554850726 and parameters: {'population_size': 247, 'n_generations': 290, 'crossover_rate': 0.5252507713041279, 'mutation_rate': 0.4854559788974996, 'elitism': 5, 'tournament_size': 4, 'max_masks': 11}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:40:28,058] Trial 108 finished with value: 0.6729584430690231 and parameters: {'population_size': 279, 'n_generations': 267, 'crossover_rate': 0.7070881960733999, 'mutation_rate': 0.4845082082505551, 'elitism': 5, 'tournament_size': 4, 'max_masks': 14}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:44:28,555] Trial 109 finished with value: 0.6258424938609486 and parameters: {'population_size': 279, 'n_generations': 267, 'crossover_rate': 0.6397333615943362, 'mutation_rate': 0.4844621753796551, 'elitism': 5, 'tournament_size': 4, 'max_masks': 19}. Best is trial 45 with value: 0.7080085475951368.
# [I 2025-01-26 22:47:02,459] Trial 117 finished with value: 0.709633813890449 and parameters: {'population_size': 272, 'n_generations': 259, 'crossover_rate': 0.6369470338994558, 'mutation_rate': 0.49921852504388053, 'elitism': 4, 'tournament_size': 4, 'max_masks': 14}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:50:01,401] Trial 118 finished with value: 0.6773459626837183 and parameters: {'population_size': 273, 'n_generations': 290, 'crossover_rate': 0.6411435220251628, 'mutation_rate': 0.48353200126099016, 'elitism': 4, 'tournament_size': 4, 'max_masks': 27}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:50:50,123] Trial 115 finished with value: 0.48624565823283405 and parameters: {'population_size': 278, 'n_generations': 259, 'crossover_rate': 0.6324224108183089, 'mutation_rate': 0.48453464975286076, 'elitism': 5, 'tournament_size': 4, 'max_masks': 14}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:51:32,971] Trial 122 finished with value: 0.6823063815787528 and parameters: {'population_size': 289, 'n_generations': 291, 'crossover_rate': 0.520900896980987, 'mutation_rate': 0.4964877739319077, 'elitism': 4, 'tournament_size': 4, 'max_masks': 14}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:51:43,269] Trial 114 finished with value: 0.6358639935745192 and parameters: {'population_size': 279, 'n_generations': 291, 'crossover_rate': 0.6421076511381602, 'mutation_rate': 0.4867943628567243, 'elitism': 5, 'tournament_size': 5, 'max_masks': 14}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:51:45,203] Trial 112 finished with value: 0.6134148937378797 and parameters: {'population_size': 246, 'n_generations': 262, 'crossover_rate': 0.6439224332079971, 'mutation_rate': 0.48872388073586764, 'elitism': 5, 'tournament_size': 4, 'max_masks': 11}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:53:04,333] Trial 123 finished with value: 0.6662686005981947 and parameters: {'population_size': 289, 'n_generations': 292, 'crossover_rate': 0.526973432558636, 'mutation_rate': 0.49109091134384797, 'elitism': 5, 'tournament_size': 4, 'max_masks': 14}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:53:59,666] Trial 104 finished with value: 0.7018535974553303 and parameters: {'population_size': 282, 'n_generations': 263, 'crossover_rate': 0.5705557578827554, 'mutation_rate': 0.4480402557577585, 'elitism': 5, 'tournament_size': 4, 'max_masks': 11}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:55:20,178] Trial 124 finished with value: 0.6712791154599204 and parameters: {'population_size': 289, 'n_generations': 291, 'crossover_rate': 0.6455795691492168, 'mutation_rate': 0.4828320180980067, 'elitism': 5, 'tournament_size': 5, 'max_masks': 14}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 22:59:11,155] Trial 113 finished with value: 0.7078742362466028 and parameters: {'population_size': 277, 'n_generations': 260, 'crossover_rate': 0.6330151697506033, 'mutation_rate': 0.48325893187742985, 'elitism': 5, 'tournament_size': 5, 'max_masks': 19}. Best is trial 117 with value: 0.709633813890449.
# [I 2025-01-26 23:03:07,707] Trial 120 finished with value: 0.7194397188649831 and parameters: {'population_size': 274, 'n_generations': 259, 'crossover_rate': 0.6347093779250451, 'mutation_rate': 0.4856209248660911, 'elitism': 4, 'tournament_size': 4, 'max_masks': 26}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:04:21,745] Trial 140 finished with value: 0.597808766000479 and parameters: {'population_size': 270, 'n_generations': 54, 'crossover_rate': 0.5939967961965462, 'mutation_rate': 0.23562635389204242, 'elitism': 4, 'tournament_size': 5, 'max_masks': 21}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:06:29,254] Trial 116 finished with value: 0.6459846549782303 and parameters: {'population_size': 245, 'n_generations': 290, 'crossover_rate': 0.5269578581978451, 'mutation_rate': 0.4849976598227488, 'elitism': 4, 'tournament_size': 5, 'max_masks': 19}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:08:27,012] Trial 130 finished with value: 0.7013315691585014 and parameters: {'population_size': 290, 'n_generations': 289, 'crossover_rate': 0.5286627817043491, 'mutation_rate': 0.490479262168009, 'elitism': 5, 'tournament_size': 5, 'max_masks': 28}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:10:58,440] Trial 139 finished with value: 0.5133846338442375 and parameters: {'population_size': 271, 'n_generations': 276, 'crossover_rate': 0.5670168721614142, 'mutation_rate': 0.38818999351509426, 'elitism': 4, 'tournament_size': 4, 'max_masks': 12}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:11:28,233] Trial 121 finished with value: 0.6695750620130175 and parameters: {'population_size': 276, 'n_generations': 291, 'crossover_rate': 0.6358349329869084, 'mutation_rate': 0.48607860505043315, 'elitism': 4, 'tournament_size': 4, 'max_masks': 21}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:15:48,013] Trial 134 finished with value: 0.7030637722122856 and parameters: {'population_size': 289, 'n_generations': 294, 'crossover_rate': 0.5307701207387155, 'mutation_rate': 0.22385665266392285, 'elitism': 4, 'tournament_size': 5, 'max_masks': 12}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:18:54,380] Trial 125 finished with value: 0.7056940423461098 and parameters: {'population_size': 290, 'n_generations': 292, 'crossover_rate': 0.5250286650588177, 'mutation_rate': 0.4864572728360559, 'elitism': 5, 'tournament_size': 5, 'max_masks': 14}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:21:10,176] Trial 146 finished with value: 0.6909709108797577 and parameters: {'population_size': 292, 'n_generations': 257, 'crossover_rate': 0.6881001883118667, 'mutation_rate': 0.4175187701341525, 'elitism': 5, 'tournament_size': 5, 'max_masks': 28}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:23:20,938] Trial 126 finished with value: 0.7188626923866425 and parameters: {'population_size': 290, 'n_generations': 292, 'crossover_rate': 0.5296574163400316, 'mutation_rate': 0.4860265622377307, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:24:58,351] Trial 131 finished with value: 0.687979324169771 and parameters: {'population_size': 290, 'n_generations': 290, 'crossover_rate': 0.5214686156461742, 'mutation_rate': 0.49883758825508057, 'elitism': 4, 'tournament_size': 5, 'max_masks': 22}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:25:30,715] Trial 136 finished with value: 0.6956398985506096 and parameters: {'population_size': 290, 'n_generations': 296, 'crossover_rate': 0.5308398609678189, 'mutation_rate': 0.4127176044347183, 'elitism': 4, 'tournament_size': 5, 'max_masks': 21}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:26:10,377] Trial 145 finished with value: 0.5192619505492582 and parameters: {'population_size': 223, 'n_generations': 126, 'crossover_rate': 0.6646640228269054, 'mutation_rate': 0.45371725602747237, 'elitism': 5, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:27:26,676] Trial 137 finished with value: 0.6892254734022164 and parameters: {'population_size': 300, 'n_generations': 273, 'crossover_rate': 0.690605016064345, 'mutation_rate': 0.4121823374816475, 'elitism': 4, 'tournament_size': 5, 'max_masks': 21}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:28:33,036] Trial 144 finished with value: 0.650313351127595 and parameters: {'population_size': 222, 'n_generations': 276, 'crossover_rate': 0.6823171706816843, 'mutation_rate': 0.38910847938112303, 'elitism': 5, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:30:02,775] Trial 141 finished with value: 0.6708963692018276 and parameters: {'population_size': 271, 'n_generations': 274, 'crossover_rate': 0.5921302476980911, 'mutation_rate': 0.4994109318085567, 'elitism': 4, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:30:48,954] Trial 133 finished with value: 0.6980498398065135 and parameters: {'population_size': 289, 'n_generations': 295, 'crossover_rate': 0.5217201788412881, 'mutation_rate': 0.4141587169151648, 'elitism': 4, 'tournament_size': 5, 'max_masks': 12}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:31:55,438] Trial 129 finished with value: 0.6535813356029809 and parameters: {'population_size': 291, 'n_generations': 290, 'crossover_rate': 0.528633982662438, 'mutation_rate': 0.4843569189475138, 'elitism': 4, 'tournament_size': 5, 'max_masks': 28}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:33:04,070] Trial 142 finished with value: 0.6649911985790736 and parameters: {'population_size': 292, 'n_generations': 273, 'crossover_rate': 0.6731287952683376, 'mutation_rate': 0.4993877015098407, 'elitism': 4, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:33:18,783] Trial 127 finished with value: 0.6926101368153688 and parameters: {'population_size': 290, 'n_generations': 292, 'crossover_rate': 0.5236661493667821, 'mutation_rate': 0.4824109391303757, 'elitism': 5, 'tournament_size': 5, 'max_masks': 26}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:35:12,388] Trial 154 finished with value: 0.4689712336478065 and parameters: {'population_size': 94, 'n_generations': 296, 'crossover_rate': 0.6550291998176243, 'mutation_rate': 0.216608990274476, 'elitism': 5, 'tournament_size': 5, 'max_masks': 25}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:37:51,016] Trial 158 finished with value: 0.6723867638954836 and parameters: {'population_size': 85, 'n_generations': 298, 'crossover_rate': 0.6576008226834394, 'mutation_rate': 0.2210937774210862, 'elitism': 5, 'tournament_size': 5, 'max_masks': 25}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:38:58,684] Trial 128 finished with value: 0.4842176757681343 and parameters: {'population_size': 291, 'n_generations': 290, 'crossover_rate': 0.5277233058877958, 'mutation_rate': 0.48005477385618206, 'elitism': 5, 'tournament_size': 5, 'max_masks': 21}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:39:23,932] Trial 143 finished with value: 0.7016034631113004 and parameters: {'population_size': 292, 'n_generations': 273, 'crossover_rate': 0.6674346853238433, 'mutation_rate': 0.45734949889505255, 'elitism': 4, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:39:49,883] Trial 119 finished with value: 0.6743305745535834 and parameters: {'population_size': 247, 'n_generations': 262, 'crossover_rate': 0.5270000637908457, 'mutation_rate': 0.48370234319754735, 'elitism': 4, 'tournament_size': 4, 'max_masks': 28}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:43:29,229] Trial 138 finished with value: 0.6993793702661529 and parameters: {'population_size': 269, 'n_generations': 297, 'crossover_rate': 0.6842651115258086, 'mutation_rate': 0.45949876465305245, 'elitism': 4, 'tournament_size': 4, 'max_masks': 12}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:45:31,883] Trial 147 finished with value: 0.7025791252487874 and parameters: {'population_size': 292, 'n_generations': 299, 'crossover_rate': 0.6721287234041075, 'mutation_rate': 0.45648550596214127, 'elitism': 4, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:45:52,099] Trial 160 finished with value: 0.6771958584221685 and parameters: {'population_size': 266, 'n_generations': 298, 'crossover_rate': 0.5034439834462905, 'mutation_rate': 0.24417020697612493, 'elitism': 5, 'tournament_size': 5, 'max_masks': 12}. Best is trial 120 with value: 0.7194397188649831.
# [I 2025-01-26 23:51:34,763] Trial 148 finished with value: 0.6811712060397777 and parameters: {'population_size': 268, 'n_generations': 298, 'crossover_rate': 0.681639336267521, 'mutation_rate': 0.2421141905321857, 'elitism': 5, 'tournament_size': 5, 'max_masks': 29}. Best is trial 120 with value: 0.7194397188649831.
# ...
# [I 2025-01-27 09:24:44,849] Trial 446 finished with value: 0.4748897756450809 and parameters: {'population_size': 286, 'n_generations': 293, 'crossover_rate': 0.732555285687159, 'mutation_rate': 0.4655830808134043, 'elitism': 5, 'tournament_size': 3, 'max_masks': 23}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:26:14,333] Trial 449 finished with value: 0.4985059636610487 and parameters: {'population_size': 284, 'n_generations': 295, 'crossover_rate': 0.6277149549942673, 'mutation_rate': 0.46784135953067457, 'elitism': 5, 'tournament_size': 3, 'max_masks': 23}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:26:33,571] Trial 455 finished with value: 0.7023156911181361 and parameters: {'population_size': 287, 'n_generations': 295, 'crossover_rate': 0.6355702499328312, 'mutation_rate': 0.4709541918210494, 'elitism': 5, 'tournament_size': 5, 'max_masks': 25}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:26:58,954] Trial 452 finished with value: 0.6774057354668395 and parameters: {'population_size': 283, 'n_generations': 293, 'crossover_rate': 0.732848084152263, 'mutation_rate': 0.4678768713272364, 'elitism': 5, 'tournament_size': 5, 'max_masks': 17}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:28:33,954] Trial 445 finished with value: 0.6797482284718458 and parameters: {'population_size': 287, 'n_generations': 294, 'crossover_rate': 0.7319573895109033, 'mutation_rate': 0.4686129049892598, 'elitism': 5, 'tournament_size': 5, 'max_masks': 23}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:30:36,831] Trial 466 finished with value: 0.5237162865738296 and parameters: {'population_size': 271, 'n_generations': 132, 'crossover_rate': 0.5364012326724998, 'mutation_rate': 0.47006087085605025, 'elitism': 5, 'tournament_size': 5, 'max_masks': 17}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:31:35,389] Trial 454 finished with value: 0.48889134155255787 and parameters: {'population_size': 288, 'n_generations': 294, 'crossover_rate': 0.6131939103196787, 'mutation_rate': 0.46779876299777373, 'elitism': 5, 'tournament_size': 5, 'max_masks': 17}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:32:52,920] Trial 457 finished with value: 0.6168634633571892 and parameters: {'population_size': 287, 'n_generations': 293, 'crossover_rate': 0.7374974823385004, 'mutation_rate': 0.47390935423703057, 'elitism': 5, 'tournament_size': 3, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:33:14,720] Trial 450 finished with value: 0.6997912901493339 and parameters: {'population_size': 286, 'n_generations': 293, 'crossover_rate': 0.7323229985903515, 'mutation_rate': 0.46766318560296427, 'elitism': 5, 'tournament_size': 5, 'max_masks': 23}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:36:38,760] Trial 470 finished with value: 0.675198415977672 and parameters: {'population_size': 270, 'n_generations': 282, 'crossover_rate': 0.5407917818999762, 'mutation_rate': 0.47579407376370025, 'elitism': 5, 'tournament_size': 5, 'max_masks': 17}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:50:38,811] Trial 461 finished with value: 0.7171222162617515 and parameters: {'population_size': 299, 'n_generations': 283, 'crossover_rate': 0.5411773556505156, 'mutation_rate': 0.47419651153608744, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:51:02,135] Trial 473 finished with value: 0.6944484051227678 and parameters: {'population_size': 272, 'n_generations': 284, 'crossover_rate': 0.539880710838412, 'mutation_rate': 0.49230449626488776, 'elitism': 5, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:51:25,510] Trial 463 finished with value: 0.6817819410809803 and parameters: {'population_size': 299, 'n_generations': 282, 'crossover_rate': 0.7323838927834515, 'mutation_rate': 0.47096419588073524, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:51:25,546] Trial 442 finished with value: 0.7153153221292047 and parameters: {'population_size': 300, 'n_generations': 293, 'crossover_rate': 0.6250754760734294, 'mutation_rate': 0.334929638316115, 'elitism': 4, 'tournament_size': 5, 'max_masks': 23}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:54:52,531] Trial 480 finished with value: 0.6834673536614954 and parameters: {'population_size': 270, 'n_generations': 284, 'crossover_rate': 0.6497166402022898, 'mutation_rate': 0.4918445984517806, 'elitism': 4, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 09:58:19,546] Trial 469 finished with value: 0.6868825104070908 and parameters: {'population_size': 270, 'n_generations': 283, 'crossover_rate': 0.6515698762673822, 'mutation_rate': 0.4731573151050017, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:04:25,466] Trial 476 finished with value: 0.5182217036768323 and parameters: {'population_size': 270, 'n_generations': 284, 'crossover_rate': 0.6504123830122109, 'mutation_rate': 0.4926676677532375, 'elitism': 4, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:06:18,079] Trial 460 finished with value: 0.6939423315898567 and parameters: {'population_size': 287, 'n_generations': 294, 'crossover_rate': 0.7916136706409256, 'mutation_rate': 0.4715646671391229, 'elitism': 5, 'tournament_size': 5, 'max_masks': 25}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:06:55,585] Trial 474 finished with value: 0.712284888090217 and parameters: {'population_size': 271, 'n_generations': 283, 'crossover_rate': 0.6498134109283431, 'mutation_rate': 0.4922751652838597, 'elitism': 4, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:09:07,335] Trial 477 finished with value: 0.4929588134585873 and parameters: {'population_size': 270, 'n_generations': 284, 'crossover_rate': 0.5482289542206711, 'mutation_rate': 0.4919519808653562, 'elitism': 4, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:10:25,097] Trial 459 finished with value: 0.5161446461511311 and parameters: {'population_size': 285, 'n_generations': 294, 'crossover_rate': 0.6123436414525789, 'mutation_rate': 0.472133761401939, 'elitism': 5, 'tournament_size': 5, 'max_masks': 25}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:14:03,744] Trial 471 finished with value: 0.6756462013982362 and parameters: {'population_size': 268, 'n_generations': 283, 'crossover_rate': 0.649209891384372, 'mutation_rate': 0.47634797898471637, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:16:01,614] Trial 478 finished with value: 0.7227719612609866 and parameters: {'population_size': 270, 'n_generations': 283, 'crossover_rate': 0.6516484341212447, 'mutation_rate': 0.49176091523330395, 'elitism': 4, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:17:21,652] Trial 468 finished with value: 0.5000386138902 and parameters: {'population_size': 270, 'n_generations': 282, 'crossover_rate': 0.6498559341543938, 'mutation_rate': 0.4757087326609509, 'elitism': 5, 'tournament_size': 5, 'max_masks': 17}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:18:02,848] Trial 479 finished with value: 0.7017200517860636 and parameters: {'population_size': 272, 'n_generations': 283, 'crossover_rate': 0.6530616170796268, 'mutation_rate': 0.4924033211898739, 'elitism': 4, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:18:16,192] Trial 482 finished with value: 0.6471507347019383 and parameters: {'population_size': 299, 'n_generations': 300, 'crossover_rate': 0.5337391461098157, 'mutation_rate': 0.4909527161529119, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:22:00,740] Trial 472 finished with value: 0.6212830014378274 and parameters: {'population_size': 269, 'n_generations': 282, 'crossover_rate': 0.6516023976270812, 'mutation_rate': 0.47667143713949933, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:22:03,011] Trial 494 finished with value: 0.4568426748538323 and parameters: {'population_size': 294, 'n_generations': 63, 'crossover_rate': 0.535145515937757, 'mutation_rate': 0.37899696770018665, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:23:18,187] Trial 486 finished with value: 0.657839912961565 and parameters: {'population_size': 297, 'n_generations': 300, 'crossover_rate': 0.5544838876196353, 'mutation_rate': 0.35011161399220075, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:26:12,019] Trial 467 finished with value: 0.5111332660095831 and parameters: {'population_size': 300, 'n_generations': 300, 'crossover_rate': 0.5407354333530381, 'mutation_rate': 0.47621857456242794, 'elitism': 5, 'tournament_size': 5, 'max_masks': 17}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:27:21,979] Trial 489 finished with value: 0.685374031987652 and parameters: {'population_size': 297, 'n_generations': 300, 'crossover_rate': 0.5564690512004469, 'mutation_rate': 0.31112735020038207, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:28:53,216] Trial 458 finished with value: 0.6961734400491031 and parameters: {'population_size': 289, 'n_generations': 294, 'crossover_rate': 0.7305457955176934, 'mutation_rate': 0.33827344603287873, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:34:50,525] Trial 483 finished with value: 0.712471990845464 and parameters: {'population_size': 299, 'n_generations': 300, 'crossover_rate': 0.5543063687727326, 'mutation_rate': 0.49256224592111303, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:36:02,950] Trial 475 finished with value: 0.49870913323083815 and parameters: {'population_size': 270, 'n_generations': 283, 'crossover_rate': 0.7656875888370808, 'mutation_rate': 0.4919294753365946, 'elitism': 4, 'tournament_size': 5, 'max_masks': 26}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:41:33,462] Trial 464 finished with value: 0.5021509953752661 and parameters: {'population_size': 270, 'n_generations': 282, 'crossover_rate': 0.5906370123565929, 'mutation_rate': 0.4758077901477264, 'elitism': 3, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:42:12,737] Trial 499 finished with value: 0.6860560561261578 and parameters: {'population_size': 300, 'n_generations': 299, 'crossover_rate': 0.5172702042288396, 'mutation_rate': 0.49932119176507567, 'elitism': 3, 'tournament_size': 5, 'max_masks': 25}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:46:05,744] Trial 488 finished with value: 0.7108952362455135 and parameters: {'population_size': 300, 'n_generations': 300, 'crossover_rate': 0.5509248434396771, 'mutation_rate': 0.4909750842736816, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:46:20,337] Trial 492 finished with value: 0.6903038237119975 and parameters: {'population_size': 300, 'n_generations': 300, 'crossover_rate': 0.5615989806936156, 'mutation_rate': 0.315356928546826, 'elitism': 3, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:48:33,047] Trial 498 finished with value: 0.6900989173575288 and parameters: {'population_size': 300, 'n_generations': 300, 'crossover_rate': 0.5503462000671691, 'mutation_rate': 0.23732945418349224, 'elitism': 3, 'tournament_size': 5, 'max_masks': 25}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:49:13,146] Trial 495 finished with value: 0.6939670543151396 and parameters: {'population_size': 298, 'n_generations': 300, 'crossover_rate': 0.7652931045873963, 'mutation_rate': 0.3396981616404675, 'elitism': 3, 'tournament_size': 5, 'max_masks': 27}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:53:34,503] Trial 491 finished with value: 0.7022811390630731 and parameters: {'population_size': 300, 'n_generations': 300, 'crossover_rate': 0.5540812342246755, 'mutation_rate': 0.3956482048494504, 'elitism': 3, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:54:33,097] Trial 485 finished with value: 0.6927949923330916 and parameters: {'population_size': 298, 'n_generations': 300, 'crossover_rate': 0.5294278525679129, 'mutation_rate': 0.3422460288503305, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:55:43,026] Trial 493 finished with value: 0.6942695598760409 and parameters: {'population_size': 292, 'n_generations': 300, 'crossover_rate': 0.5310369146512947, 'mutation_rate': 0.36312628765982535, 'elitism': 5, 'tournament_size': 5, 'max_masks': 27}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:55:58,535] Trial 497 finished with value: 0.7188896716870016 and parameters: {'population_size': 299, 'n_generations': 299, 'crossover_rate': 0.5213131601791278, 'mutation_rate': 0.32899666402943717, 'elitism': 5, 'tournament_size': 5, 'max_masks': 27}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:56:19,355] Trial 481 finished with value: 0.5114973994139441 and parameters: {'population_size': 269, 'n_generations': 284, 'crossover_rate': 0.5564426933379893, 'mutation_rate': 0.49164018933684944, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:57:35,673] Trial 496 finished with value: 0.7141848464914226 and parameters: {'population_size': 294, 'n_generations': 300, 'crossover_rate': 0.6855596928853288, 'mutation_rate': 0.49999523033201587, 'elitism': 5, 'tournament_size': 5, 'max_masks': 25}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:59:03,357] Trial 487 finished with value: 0.6876620746141996 and parameters: {'population_size': 299, 'n_generations': 300, 'crossover_rate': 0.5205156547186933, 'mutation_rate': 0.4987458667723323, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 10:59:26,681] Trial 484 finished with value: 0.49869718738926244 and parameters: {'population_size': 297, 'n_generations': 299, 'crossover_rate': 0.5903461059651943, 'mutation_rate': 0.4934112906985007, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# [I 2025-01-27 11:00:44,834] Trial 490 finished with value: 0.709243734541488 and parameters: {'population_size': 295, 'n_generations': 300, 'crossover_rate': 0.5229989136482119, 'mutation_rate': 0.3130691288926013, 'elitism': 5, 'tournament_size': 5, 'max_masks': 22}. Best is trial 152 with value: 0.7320560838275622.
# {'population_size': 265,
#  'n_generations': 299,
#  'crossover_rate': 0.6744781413262715,
#  'mutation_rate': 0.2349130096540825,
#  'elitism': 5,
#  'tournament_size': 5,
#  'max_masks': 29}

# %% [markdown]
# Based on the test results, we have decided on the following values for the paramters:
#
# - population_size: 265
# - n_generations: 300
# - crossover_rate: 0.675
# - mutation_rate: 0.235
# - elitism: 5
# - tournament_size: 5
# - max_masks: 30

# %% [markdown]
# ## Step 4: Running the algorithm
#
# Now we're ready to run the algorithm in order to find the best masks.
# In this step, we'll execute the algorithm 10 times for each wordl length between 8 and 15.
# All results for a word length are saved in a .pkl, that we can later load and analyze.

# %%
n_runs = 10

wordlist_folder = r"wordlists/trees"
word_lengths = [8, 9, 10, 11, 12, 13, 14, 15]
base_seed = 23

population_size = 265
n_generations = 300
crossover_rate = 0.675
mutation_rate = 0.235
elitism = 5
tournament_size = 5
max_masks = 30

seeds = np.random.randint(10000000, size=n_runs)

for word_length in word_lengths:
    print(f"Word length: {word_length}")
    
    filename = f"ga_{word_length}_results.pkl"
    filepath = os.path.join(outfolder, filename)
    
    if os.path.exists(filepath):
        print("Skipping")
        continue    
    
    runner = Runner(word_length, wordlist_folder, max_masks, max_cost, cost_penalty)
    results = []
    
    for n_run in range(n_runs):
        seed = seeds[n_run]
        
        print(f"Run {n_run + 1}/{n_runs}")
        ga = runner.run(population_size, n_generations, crossover_rate, mutation_rate, elitism, tournament_size, verbose=False, seed=seed)
        
        best_individual = ga.run_stats["best_individual"][-1]
        max_fitness = ga.run_stats["max_fitness"][-1]
        best_individual_matches = best_individual.get_matches(runner.wordlist_tree)
        
        results.append({
            "seed": seed,
            "word_length": word_length,
            "ga": ga,
            "best_individual": best_individual,
            "max_fitness": max_fitness,
            "best_individual_matches": best_individual_matches,
        })
        
    with open(filepath, "wb") as f:
        cloudpickle.dump(results, f)
# Out:
# Word length: 8
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 9
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 10
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 11
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 12
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 13
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 14
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10
# Word length: 15
# Run 1/10
# Run 2/10
# Run 3/10
# Run 4/10
# Run 5/10
# Run 6/10
# Run 7/10
# Run 8/10
# Run 9/10
# Run 10/10

# %% [markdown]
# ## Step 5: Analyzing results
#
# After running the algorithm, we can analyze the results obtained and compare them to the baseline.
# First, we can plot the 10 runs for each word length to see how their maximum fitness improved overtime:

# %%
import matplotlib.pyplot as plt
import cloudpickle
import os

outfolder = "results"
word_lengths = [8, 9, 10, 11, 12, 13, 14, 15]

#Create a figure and a set of subplots
fig, axs = plt.subplots(2, len(word_lengths)//2, figsize=(20, 10))

for word_length in word_lengths:
    with open(os.path.join(outfolder, f"ga_{word_length}_results.pkl"), "rb") as f:
        results = cloudpickle.load(f)
        
    max_fitnesses = [ result["max_fitness"] for result in results ]

    
    ax_x = word_lengths.index(word_length) % 2
    ax_y = word_lengths.index(word_length) // 2
    
    # Plot all runs
    for result in results:
        ga = result["ga"]               
        axs[ax_x, ax_y].plot(ga.run_stats["max_fitness"], label=f"Run {result['seed']}")
        
    axs[ax_x, ax_y].set_title(f"Word length: {word_length}")
    axs[ax_x, ax_y].set_xlabel("Generation")
    axs[ax_x, ax_y].set_ylabel("Max Fitness")
    axs[ax_x, ax_y].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that the maximum fitness for word lengths 8 and 9 appear to have stabilized before the end of the execution.
# On the other hand, the maximum fitness for word lengths 10, 11, 12, 13 and 14 were still unstable and could possibly get improved by running the algorithm for more generations.
# Lastly, the maximum fitness for word length 15 is unusual, as it appears that multiple executions arrived at the same result.

# %% [markdown]
# Next, we can show the summarized results for the executions and the baseline.

# %%
import matplotlib.pyplot as plt
import cloudpickle
import os
import pandas as pd
import json

outfolder = "results"
word_lengths = [8, 9, 10, 11, 12, 13, 14, 15]

baseline_results_filename = "baseline.json"
results_filename = "results.json"

if not os.path.exists(os.path.join(outfolder, results_filename)):
    results = {}
    
    for word_length in word_lengths:
        with open(os.path.join(outfolder, f"ga_{word_length}_results.pkl"), "rb") as f:
            results_wl = cloudpickle.load(f)
            
        # Get the best result
        best_result = max(results_wl, key=lambda x: x["max_fitness"])
        
        fitness = best_result["max_fitness"]
        masks = best_result["best_individual"].masks
        cost = best_result["best_individual"].cost
        
        results[word_length] = {
            "fitness": fitness,
            "masks": [str(mask) for mask in masks],
            "cost": cost
        }
        
    with open(os.path.join(outfolder, results_filename), "w") as f:
        json.dump(results, f)
        
with open(os.path.join(outfolder, baseline_results_filename), "r") as f:
    baseline_results = json.load(f)
    
with open(os.path.join(outfolder, results_filename), "r") as f:
    results = json.load(f)
    
corporate_results = [
    {
        "length": length,
        "fitness": result["fitness"],
        "cost": result["cost"],
        "n_masks": len(result["masks"])
    }
    for length, result in baseline_results["corporate"].items()
]

extreme_breach_results = [
    {
        "length": length,
        "fitness": result["fitness"],
        "cost": result["cost"],
        "n_masks": len(result["masks"])
    }
    for length, result in baseline_results["extreme_breach"].items()
]

genetic_results = [
    {
        "length": length,
        "fitness": result["fitness"],
        "cost": result["cost"],
        "n_masks": len(result["masks"])
    }
    for length, result in results.items()
]

results_df = pd.DataFrame(corporate_results).merge(pd.DataFrame(extreme_breach_results), on="length", suffixes=("_corporate", "_extreme_breach"))
results_df = results_df.merge(pd.DataFrame(genetic_results), on="length", suffixes=("", "_genetic"))

results_df
# Out:
#   length  fitness_corporate    cost_corporate  n_masks_corporate  \
# 0      8           0.972079  1605171098613760              22024
# 1      9           0.562294  4999603084300800              10157
# 2     10           0.386915  4998028389760000               3387
# 3     11           0.208118  4989306592000000                903
# 4     12           0.085927  4986552000000000                379
# 5     13           0.032640  4863360000000000                 56
# 6     14           0.030719  4940000000000000                 11
# 7     15           0.000000                 0                  0
#
#    fitness_extreme_breach  cost_extreme_breach  n_masks_extreme_breach  \
# 0                0.999705     4999855044508416                   58515
# 1                0.955987     4997928685184000                    5794
# 2                0.846787     4988401456221184                    1623
# 3                0.444393     2834403868825600                     119
# 4                0.175589     4411987691520000                      16
# 5                0.065720     4394348800000000                      10
# 6                0.034780     1857600000000000                       2
# 7                0.187582     3600000000000000                       2
#
#     fitness              cost  n_masks
# 0  0.998075  4998945864072960       30
# 1  0.877505  4743958039584768       28
# 2  0.719535  4732924205039616       29
# 3  0.402315  4917264338585600       16
# 4  0.206068  4858597775360000       18
# 5  0.064911  4917369600000000       11
# 6  0.043578  4991200000000000        7
# 7  0.187582  4600000000000000        3

# %%
import os
import json

resultsfolder = "results"
outfolder = os.path.join(resultsfolder, "masks")
results_filename = "results.json"
 
with open(os.path.join(resultsfolder, results_filename), "r") as f:
    results = json.load(f)
    
for word_length, result in results.items():
    with open(os.path.join(outfolder, f"masks_{word_length}.txt"), "w") as f:
        for mask in result["masks"]:
            f.write(mask + "\n")
